# %%
# %load_ext autoreload
# %autoreload 2

# %%
from compress import compress
from utils import volume_fraction
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # 1D compress

# %%
loc = np.random.random((10000)) * 100
cnt = np.ones_like(loc)
N = np.vstack((loc, cnt)).T
N_compressed = compress(N, 1.0, np.array([3.0]), 1.0)

# %%
assert np.isclose(N[:, -1].sum(), N_compressed[:, -1].sum())
assert np.isclose(volume_fraction(N, np.array([3.0]), 1.0), volume_fraction(N_compressed, np.array([3.0]), 1.0))

# %%
fig, ax = plt.subplots(figsize=(3.2,2.8), dpi=200)
ax.scatter(N[:, 0], N[:, 1], s=0.5)
ax.scatter(N_compressed[:, 0], N_compressed[:, 1], s=0.5)

# %% [markdown]
# # 2D compress

# %%
loc = np.random.random((1000, 2)) * 10
cnt = np.ones((loc.shape[0], 1))
N = np.hstack((loc, cnt))
N_compressed = compress(N, 1.0, np.array([1.0, 1.0]), 1.0)

# %%
fig, ax = plt.subplots(figsize=(3.2,2.8), dpi=200)
ax.scatter(N[:, 0], N[:, 1], s=0.5)
ax.scatter(N_compressed[:, 0], N_compressed[:, 1], s=N_compressed[:, 2])
